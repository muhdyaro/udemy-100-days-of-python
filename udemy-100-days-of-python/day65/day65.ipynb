# %% [markdown]
# ## Web Design School - How to create a website the people will love

# %%
design_principles = [
    "Typography",
    "Colour",
    "Visual hierarchy",
    "White space",
    "Alignment",
    "Consistency",
    "Images",
    "User experience",
    "Responsive design",
    "Call to action"
]

for principle in design_principles:
    print(principle)

# %%
website_structure = {
    "Header": "Navigation and branding",
    "Hero": "Main message and CTA",
    "Features": "Explain benefits",
    "Content": "Provide useful information",
    "Footer": "Additional links and information"
}

website_structure

# %%
cta_examples = [
    "Get Started",
    "Learn More",
    "Apply Now",
    "Contact Us",
    "Download",
    "Sign Up"
]

for cta in cta_examples:
    print(cta)cta_examples = [
    "Get Started",
    "Learn More",
    "Apply Now",
    "Contact Us",
    "Download",
    "Sign Up"
]

for cta in cta_examples:
    print(cta)
