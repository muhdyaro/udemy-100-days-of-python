# %% [markdown]
# ### Send Email (SMTP) & Manage Dates

# %% [markdown]
# How to Send Emails with Python using SMTP
# What is SMTP?
#
# SMTP stands for Simple Mail Transfer Protocol.
#
# It is the protocol email providers use to send emails.
#
# Python communicates with an SMTP server to send messages.

# %% [markdown]
# Example:

# %% [markdown]
# Python
#       ↓
# SMTP Server
#       ↓
# Recipient

# %%
import smtplib

connection = smtplib.SMTP("smtp.gmail.com", 587)
connection.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
# Login
connection.login(
    user="muhdayaro@gmail.com",
    password="123455678qwerty"
)

# Send mail
connection.sendmail(
    from_addr="muhdayaro@gmail.com",
    to_addrs="abdulyaro4@gmail.com",
    msg="Subject:Hello\n\nThis is my first Python email!"
)

# Close connection
connection.close()

# Or use
with smtplib.SMTP("smtp.gmail.com") as connection:
    ...
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Login
# ----> 2 connection.login(
#       3     user="your_email",
#       4     password="app_password"
#       5 )
#       7 # Send mail
#       8 connection.sendmail(
#       9     from_addr="muhdayaro@gmail.com",
#      10     to_addrs="abdulyaro4@gmail.com",
#      11     msg="Subject:Hello\n\nThis is my first Python email!"
#      12 )
#
# File c:\Users\My Pc\miniconda3\envs\arewads\lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File c:\Users\My Pc\miniconda3\envs\arewads\lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File c:\Users\My Pc\miniconda3\envs\arewads\lib\smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials ffacd0b85a97d-47f69e5eff1sm27777653f8f.19 - gsmtp')

# %% [markdown]
# #### Working with datetime

# %%
#Python include
from datetime import datetime

#Current date
now = datetime.now()
print(now)
# Out:
# 2026-07-18 23:30:00.562332

# %%
# Currrent year
print(now.year)
# Out:
# 2026

# %%
# Current month
print(now.month)
# Out:
# 7

# %%
# Current weekday
print(now.weekday())
# Out:
# 5

# %% [markdown]
# Creating your own date

# %%
birthday = datetime(
    year=2002,
    month=5,
    day=10
)
print(birthday)
# Out:
# 2002-05-10 00:00:00

# %% [markdown]
# ### Send Motivational Quotes Every Monday

# %% [markdown]
# Send Motivational Quotes on Mondays via Email.

# %%
import smtplib
import datetime as dt
import random

# Get today's date
now = dt.datetime.now()
weekday = now.weekday()

# Send email only if today is Monday (Monday = 0)
if weekday == 0:
    with open("quotes.txt", "r") as file:
        quotes = file.readlines()
        quote = random.choice(quotes)

    my_email = "muhdayaro@gmail.com"
    password = "123456789qwerty"

    with smtplib.SMTP("smtp.gmail.com") as connection:
        connection.starttls()
        connection.login(user=my_email, password=password)
        connection.sendmail(
            from_addr=my_email,
            to_addrs="recipient@gmail.com",
            msg=f"Subject:Monday Motivation\n\n{quote}"
        )

    print("Motivational quote sent successfully!")
else:
    print("Today is not Monday.")
# Out:
# Today is not Monday.

# %% [markdown]
# Day 32 is really practical, i build  projects, learn how to send email using SMPT, and automated a birthday wisher to schedule birthdays, integrates external service, API's and automation skills that are highly valuable.
