# %% [markdown]
# ### Send Email (SMTP) & Manage Dates

# %% [markdown]
# How to Send Emails with Python using SMTP
# What is SMTP?
#
# SMTP stands for Simple Mail Transfer Protocol.
#
# It is the protocol email providers use to send emails.
#
# Python communicates with an SMTP server to send messages.

# %% [markdown]
# Example:

# %% [markdown]
# Python
#       ↓
# SMTP Server
#       ↓
# Recipient

# %%
# Python Module
import smtplib

# Create a connection
connection = smtplib.SMTP("smtp.gmail.com")

#Start encryption
connection.starttls()   

# Login
connection.login(
    user="your_email",
    password="app_password"
)

# Send mail
connection.sendmail(
    from_addr="you@gmail.com",
    to_addrs="friend@gmail.com",
    msg="Subject:Hello\n\nThis is my first Python email!"
)

# Close connection
connection.close()

# Or use
with smtplib.SMTP("smtp.gmail.com") as connection:
    ...


# Important concepts TLS Keeps communication secure. Always use;
starttls()

# %% [markdown]
# #### Working with datetime

# %%
#Python include
from datetime import datetime

#Current date
now = datetime.now()

# %% [markdown]
# Creating your own date

# %%
birthday = datetime(
    year=2002,
    month=5,
    day=10
)
