# %% [markdown]
# ## Tkinter, Dynamic Typing and the Pomodoro GUI Application.

# %%
from tkinter import * 
# ---------------------------- CONSTANTS ------------------------------- #
PINK = "#e2979c"
RED = "#e7305b"
GREEN = "#9bdeac"
YELLOW = "#f7f5dd"
FONT_NAME = "Courier"
WORK_MIN = 25
SHORT_BREAK_MIN = 5
LONG_BREAK_MIN = 20

# ---------------------------- TIMER RESET ------------------------------- # 

# ---------------------------- TIMER MECHANISM ------------------------------- # 

# ---------------------------- COUNTDOWN MECHANISM ------------------------------- # 

# ----------------------  ------ UI SETUP ------------------------------- #

window = Tk()
window.title("Pamadora")
window.mainloop()

# %% [markdown]
# How to Work with the Canvas Widget and Add Images to Tkinter

# %%
window = Tk()
window.title("Pandora")
window.config(padx=100, pady=50, bg=YELLOW)
  
title_label = Label(text="Timer", fg=GREEN, bg=YELLOW, font=(FONT_NAME, 50))
title_label.grid(column=1, row=0)

canvas = Canvas(width=200, height=224, bg = YELLOW, highlightthickness=0)
tomato_img = PhotoImage(file="tomato.png")
canvas.create_image(100, 112, image=tomato_img)
canvas.create_text(100, 130, text="00:00", fill="white", font=(FONT_NAME, 35, "bold"))
canvas.grid(column=1, row=1)

start_buttton= Button(text="Start", highlightthickness=0)
start_buttton.grid(column=0, row=2)

reset_button = Button(text="reset", highlightthickness=0)
reset_button.grid(column=0, row=2)

canvas.pack()

# %%
canvas = Canvas(width=200, height=224)
canvas.create_image(100, 112, image=tomato_img)
canvas.create_text(100, 130, text="00:00")
# Out:
# 2

# %% [markdown]
# Challenge – Complete the U

# %%
      Timer

     🍅 Tomato

      25:00

Start    Reset

✔✔✔

# %% [markdown]
# Add a Count Down Mechanism
#
# This is one of the most important Tkinter lessons.

# %%
def count_down(count):
    if count > 0:
        canvas.itemconfig(timer_text, text=count)
        window.after(1000, count_down, count - 1)

# %% [markdown]
# Dynamic Typing Explained

# %%
x = 10
x = "Hello"
x = [1, 2, 3]

# %% [markdown]
# Setting Different Timer Sessions and Values
#
# Pomodoro cycle:

# %%
if reps % 8 == 0:
    long_break

elif reps % 2 == 0:
    short_break

else:
    work

# %% [markdown]
# Adding Checkmarks and Resetting the Application
#
# Completed work sessions display:

# %%
marks = ""

for _ in range(work_sessions):
    marks += "✔"

check_marks.config(text=marks)

# %%
window.after_cancel(timer)

timer_label.config(text="Timer")

canvas.itemconfig(timer_text, text="00:00")

check_marks.config(text="")

reps = 0

# %% [markdown]
# This project introduces several real-world GUI programming patterns:
#
# Event-driven programming instead of sequential execution.
# Scheduling tasks without blocking the interface.
# State management using variables like reps and timer IDs.
# Updating widgets dynamically as the application runs.
#
# These concepts carry over to desktop applications, games, dashboards, and many other Python GUI projects.
#
# You're making steady progress through the course. After completing Day 28, you'll have another polished project to add to your GitHub portfolio, showing practical experience with Tkinter and event-driven programming.
