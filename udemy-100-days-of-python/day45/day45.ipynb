# %% [markdown]
# ## Web Scrapig with BeautifulSoup

# %% [markdown]
# Today I started learning Web Scraping with Python using the BeautifulSoup library. I learned how to extract information from HTML pages and use that information in Python projects.
