# %% [markdown]
# ## Intermediate + Keys, Authentication & Enviroment Variables

# %% [markdown]
# On this day i learred what is API Authentication, how API wroks, how to send authentication API request and why we need to authenticate ourselves

# %%
import requests

API_KEY = "3d963377a57efe98f0e91427c6ea1b7a"
MY_LAT = 10.569395
MY_LONG = 7.43735

parameters = {
    "lat": MY_LAT,
    "lon": MY_LONG,
    "appid": API_KEY,
    "cnt": 4,
}

response = requests.get(
    "https://api.openweathermap.org/data/2.5/forecast",
    params=parameters
)
response.raise_for_status()

weather_data = response.json()

will_rain = False

for hour_data in weather_data["list"]:
    condition_code = hour_data["weather"][0]["id"]

    if int(condition_code) < 700:
        will_rain = True

if will_rain:
    print("Bring an umbrella ☔")
else:
    print("No rain expected.")
# Out:
# Bring an umbrella ☔

# %% [markdown]
# #### Using API Keys to Authenticate and Get the Weather from OpenWeatherMap

# %% [markdown]
# In the previous lesson i learned what is API's are and and why authentication is reqwuires. In this lesson i opoend an open whethe account use an API key to retrieve wheather forecast data from OpenWheatherApp, which will be the foundation of my raim alert project

# %%
import requests

API_KEY = "3d963377a57efe98f0e91427c6ea1b7a"

OWM_ENDPOINT = "https://api.openweathermap.org/data/2.5/forecast"

MY_LAT = 10.569395
MY_LONG = 7.43735

weather_params = {
    "lat": MY_LAT,
    "lon": MY_LONG,
    "appid": API_KEY,
}

response = requests.get(
    url=OWM_ENDPOINT,
    params=weather_params
)

response.raise_for_status()

weather_data = response.json()

print(weather_data)

print("-" * 50)

print(weather_data["list"][0])

print("-" * 50)

print(weather_data["list"][0]["weather"][0]["main"])

print(weather_data["list"][0]["weather"][0]["id"])
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1784970000, 'main': {'temp': 295.87, 'feels_like': 296.52, 'temp_min': 295.87, 'temp_max': 297.82, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 944, 'humidity': 89, 'temp_kf': -1.95, 'dew_point': 293.96}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 97}, 'wind': {'speed': 2.61, 'deg': 222, 'gust': 3.68}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-07-25 09:00:00'}, {'dt': 1784980800, 'main': {'temp': 299.16, 'feels_like': 299.16, 'temp_min': 299.16, 'temp_max': 301.29, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 943, 'humidity': 75, 'temp_kf': -2.13, 'dew_point': 294.39}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 98}, 'wind': {'speed': 2.55, 'deg': 239, 'gust': 2.63}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-07-25 12:00:00'}, {'dt': 1784991600, 'main': {'temp': 301.94, 'feels_like': 304.59, 'temp_min': 301.94, 'temp_max': 301.94, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 941, 'humidity': 65, 'temp_kf': 0, 'dew_point': 294.83}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.89, 'deg': 246, 'gust': 1.67}, 'visibility': 10000, 'pop': 0.11, 'sys': {'pod': 'd'}, 'dt_txt': '2026-07-25 15:00:00'}, {'dt': 1785002400, 'main': {'temp': 297.25, 'feels_like': 298.01, 'temp_min': 297.25, 'temp_max': 297.25, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 941, 'humidity': 88, 'temp_kf': 0, 'dew_point': 295.22}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 87}, 'wind': {'speed': 1.8, 'deg': 200, 'gust': 2.89}, 'visibility': 10000, 'pop': 0.92, 'rain': {'3h': 2.26}, 'sys': {'pod': 'n'}, 'dt_txt': '2026-07-25 18:00:00'}, {'dt': 1785013200, 'main': {'temp': 294.96, 'feels_like': 295.57, 'temp_min': 294.96, 'temp_max': 294.96, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 944, 'humidity': 91, 'temp_kf': 0, 'dew_point': 293.51}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.28, 'deg': 58, 'gust': 6.38}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 2.84}, 'sys': {'pod': 'n'}, 'dt_txt': '2026-07-25 21:00:00'}, {'dt': 1785024000, 'main': {'temp': 294.11, 'feels_like': 294.66, 'temp_min': 294.11, 'temp_max': 294.11, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 942, 'humidity': 92, 'temp_kf': 0, 'dew_point': 292.83}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 100}, 'wind': {'speed': 0.76, 'deg': 321, 'gust': 1.52}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 0.38}, 'sys': {'pod': 'n'}, 'dt_txt': '2026-07-26 00:00:00'}, {'dt': 1785034800, 'main': {'temp': 293.75, 'feels_like': 294.27, 'temp_min': 293.75, 'temp_max': 293.75, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 940, 'humidity': 92, 'temp_kf': 0, 'dew_point': 292.45}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 2, 'deg': 170, 'gust': 2.83}, 'visibility': 10000, 'pop': 0.02, 'sys': {'pod': 'n'}, 'dt_txt': '2026-07-26 03:00:00'}, {'dt': 1785045600, 'main': {'temp': 293.82, 'feels_like': 294.4, 'temp_min': 293.82, 'temp_max': 293.82, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 942, 'humidity': 94, 'temp_kf': 0, 'dew_point': 292.7}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.45, 'deg': 184, 'gust': 2.92}, 'visibility': 10000, 'pop': 0.65, 'rain': {'3h': 1.38}, 'sys': {'pod': 'd'}, 'dt_txt': '2026-07-26 06:00:00'}, {'dt': 1785056400, 'main': {'temp': 298.78, 'feels_like': 299.38, 'temp_min': 298.78, 'temp_max': 298.78, 'pressure': 1013, 'sea_level':  ...
# --------------------------------------------------
# {'dt': 1784970000, 'main': {'temp': 295.87, 'feels_like': 296.52, 'temp_min': 295.87, 'temp_max': 297.82, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 944, 'humidity': 89, 'temp_kf': -1.95, 'dew_point': 293.96}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 97}, 'wind': {'speed': 2.61, 'deg': 222, 'gust': 3.68}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-07-25 09:00:00'}
# --------------------------------------------------
# Clouds
# 804

# %% [markdown]
# #### Check if It Will Rain in the Next 12 Hours

# %% [markdown]
# In the previous lesson i successfully connected the openwhethermap API, authenticate the API key and retrieve whether forecast data. in this lesson i build core logic of the Rain alert project by checking the whether forecast for the next 12 hours and determing whether you should carry an umbrella.

# %%
import requests

API_KEY = "3d963377a57efe98f0e91427c6ea1b7a"

OWM_ENDPOINT = "https://api.openweathermap.org/data/2.5/forecast"

MY_LAT = 10.569395
MY_LONG = 7.43735

weather_params = {
    "lat": MY_LAT,
    "lon": MY_LONG,
    "appid": API_KEY,
    "cnt": 4,
}

response = requests.get(
    url=OWM_ENDPOINT,
    params=weather_params
)

response.raise_for_status()

weather_data = response.json()

will_rain = False

for hour_data in weather_data["list"]:
    condition_code = hour_data["weather"][0]["id"]

    print(f"Weather ID: {condition_code}")

    if condition_code < 700:
        will_rain = True

if will_rain:
    print("Bring an Umbrella ☔")
else:
    print("No rain expected today.")
# Out:
# Weather ID: 804
# Weather ID: 804
# Weather ID: 804
# Weather ID: 500
# Bring an Umbrella ☔

# %% [markdown]
# Instead of printing only the weather ID, print the description.

# %%
for hour_data in weather_data["list"]:
    description = hour_data["weather"][0]["description"]
    print(description)
# Out:
# overcast clouds
# overcast clouds
# overcast clouds
# light rain

# %% [markdown]
# The API also returns a forecast timestamp.

# %%
for hour_data in weather_data["list"]:
    print(hour_data["dt_txt"])
    print(hour_data["weather"][0]["main"])
# Out:
# 2026-07-25 09:00:00
# Clouds
# 2026-07-25 12:00:00
# Clouds
# 2026-07-25 15:00:00
# Clouds
# 2026-07-25 18:00:00
# Rain

# %% [markdown]
# #### Sending SMS via the Twilio API

# %% [markdown]
# Now ive compeleted the project thatll print to bring umbrella if theres rain, in this project ill send myself SMS message automatically whenever rain is expected Using Twilio API

# %%
pip install twilio

# %%
from twilio.rest import Client

ACCOUNT_SID = ""

AUTH_TOKEN = ""

client = Client(
    ACCOUNT_SID,
    AUTH_TOKEN
)

message = client.messages.create(
    body="Hello from Python!",
    from_="+15005550006",
    to="+2348012345678"
)

print(message.sid)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from twilio.rest import Client
#       3 ACCOUNT_SID = "YOUR_ACCOUNT_SID"
#       5 AUTH_TOKEN = "YOUR_AUTH_TOKEN"
#
# ModuleNotFoundError: No module named 'twilio'

# %% [markdown]
# #### Integrate with the Rain Alert Project

# %%
import requests
from twilio.rest import Client

API_KEY = ""

ACCOUNT_SID = ""

AUTH_TOKEN = ""

MY_LAT = 10.5105

MY_LONG = 7.4165

OWM_ENDPOINT = "https://api.openweathermap.org/data/2.5/forecast"

weather_params = {
    "lat": MY_LAT,
    "lon": MY_LONG,
    "appid": API_KEY,
    "cnt": 4,
}

response = requests.get(
    url=OWM_ENDPOINT,
    params=weather_params
)

response.raise_for_status()

weather_data = response.json()

will_rain = False

for hour_data in weather_data["list"]:

    condition_code = hour_data["weather"][0]["id"]

    if condition_code < 700:
        will_rain = True

if will_rain:

    client = Client(
        ACCOUNT_SID,
        AUTH_TOKEN
    )

    message = client.messages.create(
        body="☔ It is going to rain today.\nRemember to bring an umbrella!",
        from_="+15005550006",
        to="+2348012345678"
    )

    print(message.status)
else:
    print("No rain expected today.")

# %% [markdown]
# Improving the Message

# %%
description = weather_data["list"][0]["weather"][0]["description"]

# %%
message = client.messages.create(
    body=f"☔ Rain Alert!\nForecast: {description}\nDon't forget your umbrella!",
    from_="+15005550006",
    to="+2348012345678"
)

# %% [markdown]
# #### Can't Use SMS? Try WhatsApp Instead

# %% [markdown]
# In the previous lesson, i learned how to send an SMS notification using the Twilio API whenever rain is expected. However, in some countries or on Twilio trial accounts, sending SMS messages may not be available or may incur costs.

# %% [markdown]
# Twilio also provides a WhatsApp Sandbox, allowing  to send WhatsApp messages through its API. In this lesson, i modify the Rain Alert project to send a WhatsApp notification instead of an SMS.

# %%
# Instaall the Stilio SDK
pip install swilio

# %%
import requests
from twilio.rest import Client

API_KEY = "YOUR_OPENWEATHER_API_KEY"

ACCOUNT_SID = ""

AUTH_TOKEN = ""

OWM_ENDPOINT = "https://api.openweathermap.org/data/2.5/forecast"

MY_LAT = 10.5105
MY_LONG = 7.4165

weather_params = {
    "lat": MY_LAT,
    "lon": MY_LONG,
    "appid": API_KEY,
    "cnt": 4,
}

response = requests.get(
    url=OWM_ENDPOINT,
    params=weather_params
)

response.raise_for_status()

weather_data = response.json()

will_rain = False

for hour_data in weather_data["list"]:

    condition_code = hour_data["weather"][0]["id"]

    if condition_code < 700:
        will_rain = True

if will_rain:

    client = Client(
        ACCOUNT_SID,
        AUTH_TOKEN
    )

    message = client.messages.create(

        body="☔ Rain Alert!\nBring an umbrella today.",

        from_="whatsapp:",

        to="whatsapp:"

    )

    print(message.status)

else:

    print("No rain expected today.")

# %% [markdown]
# #### Use PythonAnywhere to Automate the Python Script

# %% [markdown]
# In the previous lessons, i built a Rain Alert application that checks the weather forecast and sends an SMS or WhatsApp notification if rain is expected. However, the script only runs when you execute it manually.
#
# In this lesson, i'll deploy the project to PythonAnywhere, a cloud platform that allows Python programs to run online. By scheduling script, the Rain Alert application can check the weather automatically every day—even when the computer is turned off.

# %% [markdown]
# #### Use GitHub Actions (Again) to Automate the Rain Alert Python Script

# %% [markdown]
# GitHub Actions allows to run Python scripts automatically on GitHub's cloud servers without leaving computer on. By scheduling the workflow, GitHub will check the weather every day and send you an SMS or WhatsApp message if rain is expected.
