# %% [markdown]
# ### Web Development - Introduction to HTML

# %% [markdown]
# how does the internet works?

# %% [markdown]
# download the required software from VS code to Chrome

# %% [markdown]
# ## what is html?

# %% [markdown]
# my first html page:

# %%
#Tells the browser im  using HTML5.
<!DOCTYPE html>

#root element
<html>

#contains metadata.
<head>

#appears on the browser tab.
    <title>My First Website</title>
</head>

#everything visible on the webpage.
<body>

</body>

</html>

# %% [markdown]
# ## html haeding elements

# %%
<!DOCTYPE html>
<html>

<head>
    <title>Heading Practice</title>
</head>

<body>

<h1>This is Heading 1</h1>

<h2>This is Heading 2</h2>

<h3>This is Heading 3</h3>

<h4>This is Heading 4</h4>

<h5>This is Heading 5</h5>

<h6>This is Heading 6</h6>

</body>

</html>

# %% [markdown]
# ## html paraghraph

# %%
<!DOCTYPE html>
<html>

<head>
    <title>Paragraph Example</title>
</head>

<body>

<h1>About Me</h1>

<p>
Hi, I'm Muhammad.
I'm learning Web Development.
</p>

<p>
This is my second paragraph.
</p>

</body>

</html>

# %% [markdown]
# ## self closig tags

# %%
#link break
<br />


#horizantal
<hr />

# %%
<!DOCTYPE html>
<html>

<head>
    <title>Self Closing Tags</title>
</head>

<body>

<h1>My Resume</h1>

<hr />

<p>I love Python.</p>

<br />

<p>I also enjoy HTML.</p>

</body>

</html>

# %% [markdown]
# ## project - Movie ranking

# %%
<!DOCTYPE html>
<html>

<head>
    <title>Movie Ranking Project</title>
</head>

<body>

<h1>The Best Movies According to Muhammad</h1>

<h2>My Top 3 Movies of All Time</h2>

<hr />

<h3>Interstellar</h3>

<p>
A masterpiece of science fiction with amazing visuals,
emotional storytelling, and incredible music.
</p>

<h3>Inception</h3>

<p>
A brilliant movie that explores dreams within dreams.
It keeps you thinking from beginning to end.
</p>

<h3>The Dark Knight</h3>

<p>
One of the greatest superhero films ever made.
Heath Ledger's Joker performance is unforgettable.
</p>

</body>

</html>
