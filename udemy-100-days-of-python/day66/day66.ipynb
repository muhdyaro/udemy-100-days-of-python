# %% [markdown]
# ## Building a REST API with Flask — Part 1

# %% [markdown]
# What is REST?
#
# REST stands for:
#
# Representational State Transfer
#
# You don't need to memorize the definition. The important idea is that REST APIs use HTTP requests to work with resources.
