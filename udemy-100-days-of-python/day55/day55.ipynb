# %% [markdown]
# ## HTML & URL Parsing in Flask & the Higher Lower Game

# %% [markdown]
# 1. install flask

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. first flask url path

# %%
from flask import Flask

app = Flask(__name__)

# %% [markdown]
# 3. adding another url

# %%
@app.route("/about")
def about():
    return "This is the About Page"

# %% [markdown]
# 4. running flask

# %%
if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\My Pc\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from flask import Flask

app = Flask(__name__)


@app.route("/")
def home():
    return "Hello, World!"


@app.route("/about")
def about():
    return "This is the About Page"


if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [markdown]
# 5. understanding dynamic urls

# %%
@app.route("/user/<name>")
def greet(name):
    return f"Hello {name}"

# %%
@app.route("/number/<int:number>")
def show_number(number):
    return f"The number is {number}"

# %% [markdown]
# 6. rendering html with flask

# %%
@app.route("/")
def home():
    return "<h1>Hello Muhammad!</h1>"

# %% [markdown]
# 7. styling html with python decorators

# %%
def make_bold(function):
    def wrapper():
        return f"<b>{function()}</b>"
    
    return wrapper

# %% [markdown]
# using it;

# %%
@make_bold
def greeting():
    return "Hello!"

# %% [markdown]
# call;

# %%
greeting()
# Out:
# '<b>Hello!</b>'

# %% [markdown]
# creating multiple html decorators

# %%
def make_bold(function):
    def wrapper():
        return f"<b>{function()}</b>"
    return wrapper


def make_emphasis(function):
    def wrapper():
        return f"<em>{function()}</em>"
    return wrapper


def make_underline(function):
    def wrapper():
        return f"<u>{function()}</u>"
    return wrapper

# %%
@make_bold
@make_emphasis
@make_underline
def greeting():
    return "Hello!"

# %% [markdown]
# 8. advanced decoders *args and **kwargs

# %%
def decorator_function(function):
    def wrapper():
        return function()
    
    return wrapper

# %%
def decorator_function(function):
    def wrapper(*args, **kwargs):
        return function(*args, **kwargs)
    
    return wrapper

# %% [markdown]
# unserstanding *args

# %%
def add_numbers(*args):
    total = 0

    for number in args:
        total += number

    return total

# %%
add_numbers(1, 2, 3, 4, 5)
# Out:
# 15

# %% [markdown]
# understanding **kwargs

# %%
def display_information(**kwargs):
    for key, value in kwargs.items():
        print(key)
        print(value)

# %%
display_information(
    name="Muhammad",
    language="Python",
    level="Intermediate"
)
# Out:
# name
# Muhammad
# language
# Python
# level
# Intermediate

# %% [markdown]
# 9. building the higher or lower game

# %%
from flask import Flask
import random

app = Flask(__name__)

random_number = random.randint(0, 9)


@app.route("/")
def home():
    return """
    <h1>Guess a number between 0 and 9</h1>
    <p>Type your guess in the URL.</p>
    """


@app.route("/<int:number>")
def guess(number):

    if number < random_number:
        return """
        <h1 style="color: red;">Too Low, Try Again!</h1>
        """

    elif number > random_number:
        return """
        <h1 style="color: purple;">Too High, Try Again!</h1>
        """

    else:
        return """
        <h1 style="color: green;">You found me! 🎉</h1>
        """


if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [markdown]
# 11. how the game works

# %%
random_number = random.randint(0, 9)

# %%
http://127.0.0.1:5000/3

# %%
if number < random_number:

# %% [markdown]
# 12. improved verison with images

# %%
from flask import Flask
import random

app = Flask(__name__)

random_number = random.randint(0, 9)


@app.route("/")
def home():
    return """
    <h1>Guess a number between 0 and 9</h1>
    """


@app.route("/<int:number>")
def guess(number):

    if number < random_number:
        return """
        <h1 style="color: red;">Too Low! Try Again!</h1>
        <img src="https://media.giphy.com/media/jD4DwBtqPXRXa/giphy.gif">
        """

    elif number > random_number:
        return """
        <h1 style="color: purple;">Too High! Try Again!</h1>
        <img src="https://media.giphy.com/media/3o6ZtaO9BZHcOjmErm/giphy.gif">
        """

    else:
        return """
        <h1 style="color: green;">You found me! 🎉</h1>
        """


if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [markdown]
# running it again with jupiter notebook

# %%
import random

# %%
random_number = random.randint(0, 9)

print(random_number)
# Out:
# 3

# %%
def add(*args):
    total = 0

    for number in args:
        total += number

    return total


print(add(1, 2, 3, 4, 5))
# Out:
# 15

# %%
def user_info(**kwargs):

    for key, value in kwargs.items():
        print(f"{key}: {value}")


user_info(
    name="Muhammad",
    course="100 Days of Python",
    day=55
)
# Out:
# name: Muhammad
# course: 100 Days of Python
# day: 55

# %%
def make_bold(function):

    def wrapper():
        return f"<b>{function()}</b>"

    return wrapper


@make_bold
def greeting():
    return "Hello, World!"


print(greeting())
