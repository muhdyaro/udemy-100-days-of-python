# %% [markdown]
# ## Templating with jinja in Flask Applications

# %% [markdown]
# 1. install required libraries

# %%
# !pip install flask requests
# Out:
# Requirement already satisfied: flask in c:\users\my pc\miniconda3\lib\site-packages (3.1.3)
# Requirement already satisfied: requests in c:\users\my pc\miniconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\my pc\miniconda3\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\my pc\miniconda3\lib\site-packages (from flask) (8.5.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\my pc\miniconda3\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\my pc\miniconda3\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\my pc\miniconda3\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\my pc\miniconda3\lib\site-packages (from flask) (3.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\my pc\miniconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\my pc\miniconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\my pc\miniconda3\lib\site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\my pc\miniconda3\lib\site-packages (from requests) (2023.11.17)

# %% [markdown]
# 2. import libraries

# %%
from flask import Flask, render_template
import requests

# %% [markdown]
# 3. get blog from data api

# %%
response = requests.get(
    "https://api.npoint.io/c790b4d5cab58020d391"
)

posts = response.json()

print(posts)

# %% [markdown]
# 4. create the flask application

# %%
from flask import Flask, render_template
import requests

app = Flask(__name__)


@app.route("/")
def home():

    response = requests.get(
        "https://api.npoint.io/c790b4d5cab58020d391"
    )

    posts = response.json()

    return render_template(
        "index.html",
        posts=posts
    )


if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# 5. create index.html

# %%
<!DOCTYPE html>

<html lang="en">

<head>

    <meta charset="UTF-8">

    <meta name="viewport"
          content="width=device-width, initial-scale=1.0">

    <title>My Blog</title>

</head>


<body>

    <h1>My Blog</h1>

    <p>Welcome to my blog website!</p>


    {% for post in posts %}

        <h2>{{ post.title }}</h2>

        <p>{{ post.subtitle }}</p>

        <p>{{ post.body }}</p>

        <hr>

    {% endfor %}


</body>

</html>

# %% [markdown]
# 6. add dynamic blog page

# %%
from flask import Flask, render_template
import requests

app = Flask(__name__)


response = requests.get(
    "https://api.npoint.io/c790b4d5cab58020d391"
)

posts = response.json()


@app.route("/")
def home():

    return render_template(
        "index.html",
        posts=posts
    )


@app.route("/post/<int:post_id>")
def show_post(post_id):

    requested_post = None

    for post in posts:

        if post["id"] == post_id:

            requested_post = post

    return render_template(
        "post.html",
        post=requested_post
    )


if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# 7. update index.html

# %%
<!DOCTYPE html>

<html lang="en">

<head>

    <meta charset="UTF-8">

    <meta name="viewport"
          content="width=device-width, initial-scale=1.0">

    <title>My Blog</title>

</head>


<body>

    <h1>My Blog</h1>


    {% for post in posts %}

        <h2>
            <a href="{{ url_for('show_post', post_id=post.id) }}">
                {{ post.title }}
            </a>
        </h2>

        <p>{{ post.subtitle }}</p>

        <hr>

    {% endfor %}


</body>

</html>

# %% [markdown]
# 8. create post.html

# %%
<!DOCTYPE html>

<html lang="en">

<head>

    <meta charset="UTF-8">

    <meta name="viewport"
          content="width=device-width, initial-scale=1.0">

    <title>{{ post.title }}</title>

</head>


<body>

    <h1>{{ post.title }}</h1>

    <h3>{{ post.subtitle }}</h3>

    <p>{{ post.body }}</p>


    <br>

    <a href="{{ url_for('home') }}">
        Back to Home
    </a>


</body>

</html>
