# %% [markdown]
#  # 🎯Day 9: Dictionaries, Nesting & the Secret Auction Project

# %% [markdown]
# Its day 9 and I Learn how to store, organize, and retrieve complex data using Python dictionaries - and apply these concepts to build my own Secret Auction Program 🪙.
# The Deep hive: Ive covered how to create and use dictionaries, Storing data as key–value pairs, Adding new items and modifying existing ones, Looping through a dictionary.
# Example:

# %%
programming_dictionary = {
    "Bug": "An error in a program that prevents it from running as expected.",
    "Function": "A block of code which can be called multiple times."
}

# Accessing and updating
print(programming_dictionary["Bug"])
programming_dictionary["Loop"] = "Doing something repeatedly."
# Out:
# An error in a program that prevents it from running as expected.

# %% [markdown]
# 🧮 Coding Exercise 9: Grading Program
# In this part I've convert student scores into grades using a dictionary.
# Example Code:

# %%
student_scores = {
    "Harry": 81,
    "Ron": 78,
    "Hermione": 99,
    "Draco": 74,
    "Neville": 62,
}

student_grades = {}

for student in student_scores:
    score = student_scores[student]
    if score > 90:
        student_grades[student] = "Outstanding"
    elif score > 80:
        student_grades[student] = "Exceeds Expectations"
    elif score > 70:
        student_grades[student] = "Acceptable"
    else:
        student_grades[student] = "Fail"

print(student_grades)
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %% [markdown]
# Nesting Lists and Dictionaries: Ive also go through nesting, list and dictionaries where Iearned how to work with them.
# Example:

# %% [markdown]
# 1.Nesting dictionary inside another dictionary

# %%
travel_log = {
    "France": {"cities_visited": ["Paris", "Lille"], "total_visits": 12},
    "Germany": {"cities_visited": ["Berlin", "Hamburg"], "total_visits": 5},
}

# %% [markdown]
# 2. Nesting a dictionary inside a list:

# %%
travel_log = [
    {
        "country": "France",
        "cities_visited": ["Paris", "Lille"],
        "total_visits": 12
    },
    {
        "country": "Germany",
        "cities_visited": ["Berlin", "Hamburg"],
        "total_visits": 5
    }
]

# %%
# 🚀 The Secret Auction Program


import os



print("Welcome to the Secret Auction Program!")

# Step 1: Create an empty dictionary to store all bids
bids = {}

# Step 2: Define a function to find the highest bidder
def find_highest_bidder(bidding_record):
    highest_bid = 0
    winner = ""
    # Loop through the dictionary to find the highest bid
    for bidder in bidding_record:
        bid_amount = bidding_record[bidder]
        if bid_amount > highest_bid:
            highest_bid = bid_amount
            winner = bidder
    # Print out the winner
    print(f"\n🏆 The winner is {winner} with a bid of ${highest_bid}!\n")

# Step 3: Control variable for the bidding loop
bidding_finished = False

# Step 4: Main program loop
while not bidding_finished:
    name = input("What is your name?: ")
    price = int(input("What is your bid?: $"))

    # Store name and bid in the dictionary
    bids[name] = price

    should_continue = input("Are there any other bidders? Type 'yes' or 'no': ").lower()

    if should_continue == "no":
        # No more bidders — find the winner
        bidding_finished = True
        find_highest_bidder(bids)
    elif should_continue == "yes":
        # Clear the screen for the next bidder
        os.system('cls' if os.name == 'nt' else 'clear')
# Out:
# Welcome to the Secret Auction Program!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 35
#      33 # Step 4: Main program loop
#      34 while not bidding_finished:
# ---> 35     name = input("What is your name?: ")
#      36     price = int(input("What is your bid?: $"))
#      38     # Store name and bid in the dictionary
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py:1261, in Kernel.raw_input(self, prompt)
#    1259     msg = "raw_input was called, but this frontend does not support input requests."
#    1260     raise StdinNotImplementedError(msg)
# -> 1261 return self._input_request(
#    1262     str(prompt),
#    1263     self._parent_ident["shell"],
#    1264     self.get_parent("shell"),
#    1265     password=False,
#    1266 )
#
# ...
